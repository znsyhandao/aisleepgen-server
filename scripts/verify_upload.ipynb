# %%
# 检查文件是否存在
model_path = "/content/drive/MyDrive/models/Janus-1.3B"
required_files = ["config.json", "model.safetensors", "tokenizer.json"]

for file in required_files:
    if not os.path.exists(os.path.join(model_path, file)):
        print(f"缺失文件: {file}")
    else:
        print(f"文件存在: {file}")

# 检查文件大小
# !du -sh "/content/drive/MyDrive/models/Janus-1.3B"
